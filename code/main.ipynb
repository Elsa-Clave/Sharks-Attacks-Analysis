# %% [markdown]
# ## 🦈 Sharks Attacks

# %% [markdown]
# ### 1. Cleaning the dataset

# %%
#Imorting libraries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
#Load csv file from the "datasets" folder and name the dataframe in this case "sharks"
sharks = pd.read_csv("datasets/attacks.csv", encoding= "ISO-8859-1")

# %% [markdown]
# [Exploring the Meta-info and exploring the DataSet]

# %%
#First general information of the dataframe. Meta-info(shape, columns, dtypes and info) "display" (head, sample)
#That is --> Exploratory analysis
sharks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
sharks.shape
# Out:
# (25723, 24)

# %%
sharks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
sharks.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
sharks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
# Checking "null" values ​​in the dataframe in different ways.
missing_values = pd.isnull(sharks)

# %%
#Null values ​​per column
missing_counts = missing_values.sum()

# %%
#Count of columns with null values
columns_with_missing = missing_counts[missing_counts > 0].count()

# %%
# Check if all columns have a null value
all_columns_missing = missing_counts.all()

# %%
# Calculate the total number of null values
total_missing_values = missing_counts.sum()

# %%
# View results
print("Missing Values in Each Column:\n", missing_counts)
print("\nNumber of Columns with Missing Values:", columns_with_missing)
print("All Columns Have Missing Values:", all_columns_missing)
print("\nTotal Missing Values in the DataFrame:", total_missing_values)
# Out:
# Missing Values in Each Column:
#  Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64
#
# Number of Columns with Missing Values: 24
# All Columns Have Missing Values: True
#
# ...

# %%
#Another way to visualize it.
pd.isnull(sharks)
# Out:
#        Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0            False  False  False  False    False  False     False     False
# 1            False  False  False  False    False  False     False     False
# 2            False  False  False  False    False  False     False     False
# 3            False  False  False  False    False  False     False     False
# 4            False  False  False  False    False  False     False     False
# ...            ...    ...    ...    ...      ...    ...       ...       ...
# 25718         True   True   True   True     True   True      True      True
# 25719         True   True   True   True     True   True      True      True
# 25720         True   True   True   True     True   True      True      True
# 25721         True   True   True   True     True   True      True      True
# 25722        False   True   True   True     True   True      True      True
#
# ...

# %% [markdown]
# #### Exploring The International Shark Attack File (ISAF) or Global Shark Attack File (GSAF)
# <details>
#   <summary>What columns does it contain?: Columns that are NOT interesting</summary>
#
# - Case number: case number (date format??) is the same as the date (value)
# - Year: year (it is in float, maybe it will have to be fixed)
# - Name: Not relevant
# - Sex: maybe
# - Injury: Each observation is different and too specific
# - Time: Not relevant
# - Species:
# - Investigator or source: Not relevant
# - pdf: Not relevant
# - href formula: Not relevant
# - href: Not relevant
# - Case number.1:Interested? No
# - Case number.2:Interested? No
# - original order: Not relevant
# - Unamed 22: Interested? No
# - Unamed 23: Interested? No

# %%
# Selecting some columns to keep: (could be done the other way around, deleted with drop too)
keep_columns = ["Date", "Year", "Type", "Country", "Area", "Activity", "Sex ", "Age", "Fatal (Y/N)", "Species "]
sharks = sharks[keep_columns] 
sharks.head()
# Out:
#           Date    Year        Type    Country             Area     Activity  \
# 0  25-Jun-2018  2018.0     Boating        USA       California     Paddling
# 1  18-Jun-2018  2018.0  Unprovoked        USA          Georgia     Standing
# 2  09-Jun-2018  2018.0     Invalid        USA           Hawaii      Surfing
# 3  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales      Surfing
# 4  04-Jun-2018  2018.0    Provoked     MEXICO           Colima  Free diving
#
#   Sex   Age Fatal (Y/N)         Species
# 0    F   57           N      White shark
# 1    F   11           N              NaN
# 2    M   48           N              NaN
# 3    M  NaN           N        2 m shark
# 4    M  NaN           N  Tiger shark, 3m

# %%
#Fix column names (all lowercase and remove spaces)
sharks.columns = [i.lower().strip()for i in sharks.columns]
sharks.sample()
# Out:
#       date  year type country area activity  sex  age fatal (y/n) species
# 16789  NaN   NaN  NaN     NaN  NaN      NaN  NaN  NaN         NaN     NaN

# %%
#Change names individually: with df=df.rename(columns={"old":"new"})
sharks = sharks.rename(columns = {"fatal (y/n)": "fatal"})

# %% [markdown]
# #### How to delete ROWS whose values ​​are ALL null?
# <details>
#   <summary>dropna(self, axis=0, how="all", thresh=None, subset=None, inplace=False)</summary>
#
# - axis: {0 (or 'index'), 1 (or 'columns')}, default 0
# - If 0, drop rows with missing values.
# - If 1, drop columns with missing values.
# - how: {'any', 'all'}, default 'any'
# - If 'any', drop the row or column if any of the values is NA.
# - If 'all', drop the row or column if all of the values are NA.
# - thresh: (optional) an int value to specify the threshold for the drop operation.
# - subset: (optional) column label or sequence of labels to specify rows or columns.
# - inplace: (optional) a bool value.
# - If True, the source DataFrame is changed and None is returned.

# %%
#Delete rows that have all values ​​​​null (display):
sharks.dropna(axis=0, how="all", inplace=False)
# Out:
#              date    year        type             country               area  \
# 0     25-Jun-2018  2018.0     Boating                 USA         California
# 1     18-Jun-2018  2018.0  Unprovoked                 USA            Georgia
# 2     09-Jun-2018  2018.0     Invalid                 USA             Hawaii
# 3     08-Jun-2018  2018.0  Unprovoked           AUSTRALIA    New South Wales
# 4     04-Jun-2018  2018.0    Provoked              MEXICO             Colima
# ...           ...     ...         ...                 ...                ...
# 6297  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6298  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6299    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6300    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6301    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
# ...

# %%
#We definitively eliminate.
sharks.dropna(axis=0, how="all", inplace=True)

# %%
#What to do with missing values ​​of column "year" to convert to "int"
sharks[sharks["year"].isnull()]
# Out:
#                       date  year        type    country        area  \
# 187   Reported 08-Jan-2017   NaN     Invalid  AUSTRALIA  Queensland
# 6079  Reported 19-Aug-1836   NaN  Unprovoked    ENGLAND  Cumberland
#
#           activity sex  age fatal     species
# 187   Spearfishing   M   35   NaN  Bull shark
# 6079      Swimming   M  NaN     Y         NaN

# %%
# In the date column it reveals the specific year:
sharks.loc[187, "year"] = 2017

# %%
sharks.loc[6079, "year"] = 1836

# %%
#Change the "year" column from float to int:
sharks["year"] = sharks["year"].astype("int")

# %%
# Confirming that the change is correct:
sharks["year"].dtype
# Out:
# dtype('int32')

# %%
#Review of how we are dealing with nulls and what to do with each case.
sharks.isna().sum()
# Out:
# date           0
# year           0
# type           4
# country       50
# area         455
# activity     544
# sex          565
# age         2831
# fatal        539
# species     2838
# dtype: int64

# %%
#I begin to formulate some hypothesis and from this, create specific subsets and clean them well

# %%
#See from which year there is enough data (1800)
plt.hist(x="year", data=sharks, bins=90)
plt.xlim([1700, sharks["year"].max()])
# Out:
# (1700.0, 2018.0)

# %%
sharks.shape
# Out:
# (6302, 10)

# %%
sharks["type"].value_counts()
# Out:
# type
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# Questionable       2
# Boatomg            1
# Name: count, dtype: int64

# %%
#Check how many duplicates there are to clean them
sharks.duplicated().sum()
# Out:
# 27

# %%
sharks.drop_duplicates(inplace=True)

# %% [markdown]
# ### Breaking the project down into different subsets and Hypothesis
# #### 1st HYPOTHESIS: Sharks dislike surfers, especially male surfers.

# %%
#Let's create a subset and clean it in order to develop further the hypothesis.
#We'll need the columns "activity", "sex" and "fatal".
h1 = sharks.copy()
h1_columns = ["activity", "sex", "fatal"]
h1 = h1[h1_columns]
h1.head()
# Out:
#       activity sex fatal
# 0     Paddling   F     N
# 1     Standing   F     N
# 2      Surfing   M     N
# 3      Surfing   M     N
# 4  Free diving   M     N

# %%
#Let's see the values in the fatal column
h1["fatal"].value_counts()
# Out:
# fatal
# N          4274
# Y          1381
# UNKNOWN      70
#  N            7
# M             1
# 2017          1
# N             1
# y             1
# Name: count, dtype: int64

# %%
#Adressing the issues:
h1.loc[h1["fatal"] == " N", "fatal"] = "N"
h1.loc[h1["fatal"] == "M", "fatal"] = "UNKNOWN"
h1.loc[h1["fatal"] == "2017", "fatal"] = "UNKNOWN"
h1.loc[h1["fatal"] == "y", "fatal"] = "Y"
h1.loc[h1["fatal"] == "N ", "fatal"] = "N"
h1["fatal"].value_counts()
# Out:
# fatal
# N          4282
# Y          1382
# UNKNOWN      72
# Name: count, dtype: int64

# %%
h1["sex"].value_counts()
# Out:
# sex
# M      5070
# F       635
# M         2
# N         2
# lli       1
# .         1
# Name: count, dtype: int64

# %%
h1.loc[h1["sex"] == "M ", "sex"] = "M"
h1.loc[h1["sex"] == "N", "sex"] = "UNKNOWN"
h1.loc[h1["sex"] == "lli", "sex"] = "UNKNOWN"
h1.loc[h1["sex"] == ".", "sex"] = "UNKNOWN"
h1["sex"].value_counts()
# Out:
# sex
# M          5072
# F           635
# UNKNOWN       4
# Name: count, dtype: int64

# %%
h1["activity"].value_counts()
# Out:
# activity
# Surfing                                   966
# Swimming                                  865
# Fishing                                   430
# Spearfishing                              331
# Bathing                                   160
#                                          ...
# Playing with a frisbee in the shallows      1
# Sinking of the ferryboat Dumaguete          1
# Wreck of the Storm King                     1
# Feeding mullet to sharks                    1
# Wreck of  large double sailing canoe        1
# Name: count, Length: 1532, dtype: int64

# %%
#From the "activity" column keeping the most relevant-repeated observations
activities_to_keep = ['Surfing', 'Swimming', 'Fishing', 'Spearfishing', 'Bathing', 'Paddling', 'Standing,','Scuba diving','Snorkeling','Kayaking','Wading','Sea disaster']
filtered_h1 = h1[h1['activity'].isin(activities_to_keep)]
filtered_h1.value_counts()
filtered_h1.shape
# Out:
# (3109, 3)

# %%
# Matplotlib inline to visualize Matplotlib graphs
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'

# %%
#Checking the activities related to most attacks
activities = filtered_h1['activity'].value_counts()
activities.plot.barh(color='turquoise')
plt.savefig("test.png")

# %%
#Starting point, count of activities by sex
custom_palette = {
    'M': 'turquoise',
    'F': 'teal'
}
fig = px.bar(filtered_h1, x='sex', color='sex', title='Count of activities by sex', color_discrete_map=custom_palette)
fig.update_layout(xaxis_title='Sex', yaxis_title='Count', legend_title='Sex')
fig.show()
# Out:
# c:\Users\Elsa\anaconda3\envs\IronHackTest\Lib\site-packages\plotly\express\_core.py:2065: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   sf: grouped.get_group(s if len(s) > 1 else s[0])

# %%
#Digging more into Fatalities (this changes things)
grouped_data = filtered_h1.groupby(['activity', 'sex', 'fatal']).size().reset_index(name='count')
fatalities_data = filtered_h1[filtered_h1['fatal'] == 'Y']
color_palette = ['teal', 'turquoise']

fig = px.bar(fatalities_data, 
             x='activity', 
             color='sex', 
             barmode='group',
             title='Fatalities by activity and sex',
             labels={'count': 'Count of Fatalities', 'activity': 'Activity'},
             category_orders={'activity': sorted(fatalities_data['activity'].unique())},
             color_discrete_sequence=color_palette
            )
fig.show()
# Out:
# c:\Users\Elsa\anaconda3\envs\IronHackTest\Lib\site-packages\plotly\express\_core.py:2065: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.

# %%
sns.countplot(data=filtered_h1, x="sex", hue="fatal", color="turquoise")
# Out:
# C:\Users\Elsa\AppData\Local\Temp\ipykernel_5740\4108287774.py:1: FutureWarning:
#
#
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:turquoise'` for the same effect.
# <Axes: xlabel='sex', ylabel='count'>

# %%
total_fatalities = filtered_h1['fatal'].eq('Y').sum()

# Group the data by 'sex' and calculate the count of fatalities for each sex
fatalities_by_sex = filtered_h1[filtered_h1['fatal'] == 'Y'].groupby('sex').size()

# Calculate the proportion of fatalities by sex
proportion_fatality = (fatalities_by_sex / total_fatalities) * 100

plt.figure(figsize=(8, 6)) 
proportion_fatality.plot(kind='bar', color=['turquoise', 'teal'])
plt.title('Proportion of Fatalities by Sex')
plt.xlabel('Sex')
plt.ylabel('Proportion of Fatalities (%)')
plt.xticks(rotation=0)  
plt.grid(axis='y')  
plt.show()

# %% [markdown]
# #### 2nd HYPOTHESIS: Sharks from Australia are more chill compared to americans
# Depending not on the attack but the fatality.

# %%
#Let's create the next subset
h2 = sharks.copy()
h2_columns = ["country", "fatal", "year"]
h2 = h2[h2_columns]
h2.head()
# Out:
#      country fatal  year
# 0        USA     N  2018
# 1        USA     N  2018
# 2        USA     N  2018
# 3  AUSTRALIA     N  2018
# 4     MEXICO     N  2018

# %%
h2["country"].value_counts()
# Out:
# country
# USA                       2222
# AUSTRALIA                 1334
# SOUTH AFRICA               578
# PAPUA NEW GUINEA           133
# NEW ZEALAND                127
#                           ...
# MALDIVE ISLANDS              1
# NICARAGUA                    1
# NORTH SEA                    1
# RED SEA / INDIAN OCEAN       1
# CEYLON (SRI LANKA)           1
# Name: count, Length: 212, dtype: int64

# %%
#Keeping only values for the top 15 countries with more observations
country_counts = h2['country'].value_counts()
top_15_countries = country_counts.head(15).index.tolist()
h2 = h2[h2['country'].isin(top_15_countries)]

# %%
#Keeping data only starting from 1800
h2 = h2[h2["year"] >= 1800]

# %%
h2.shape
# Out:
# (4978, 3)

# %%
h2.loc[h2["fatal"] == " N", "fatal"] = "N"
h2.loc[h2["fatal"] == "M", "fatal"] = "UNKNOWN"
h2.loc[h2["fatal"] == "2017", "fatal"] = "UNKNOWN"
h2.loc[h2["fatal"] == "y", "fatal"] = "Y"
h2.loc[h2["fatal"] == "N ", "fatal"] = "N"
h1["fatal"].value_counts()
# Out:
# fatal
# N          4282
# Y          1382
# UNKNOWN      72
# Name: count, dtype: int64

# %%
h2 = h2[h2['fatal'] != 'UNKNOWN']

# %%
#stacked bar chart can show the distribution of fatal and non-fatal incidents by country
stacked_df = h2.groupby(['country', 'fatal']).size().unstack(fill_value=0)
stacked_df.plot(kind='bar', stacked=True, figsize=(12, 6), color=['turquoise', 'teal'])
plt.title('Fatal Incidents by Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Fatal')
plt.show()

# %%
#the trend of fatal incidents over the years
fatal_by_year = h2.groupby('year')['fatal'].value_counts().unstack(fill_value=0)
fatal_by_year.plot(kind='line', figsize=(12, 6), color=['turquoise', 'teal'])
plt.title('Trend of Fatal Incidents Over Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
#distribution of fatal incidents by country
plt.figure(figsize=(12, 6))
sns.boxplot(x='country', y='year', hue='fatal', data=h2,palette={'N': 'turquoise', 'Y': 'teal'})
plt.title('Distribution of Fatal Incidents by Country')
plt.xlabel('Country')
plt.ylabel('Year')
plt.xticks(rotation=45)
plt.legend(title='Fatal')
plt.show()

# %%
#correlation between countries and fatal incidents
import matplotlib.colors as mcolors
custom_colors = ['#007777', '#008888', '#009999', '#00aaaa', '#00bbbb', '#00cccc']
cmap_custom = mcolors.LinearSegmentedColormap.from_list("CustomTurquoiseTeal", custom_colors)
heatmap_df = h2.pivot_table(index='country', columns='fatal', aggfunc='size', fill_value=0)
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_df, cmap=cmap_custom, annot=True, fmt='d')  # Using custom colormap
plt.title('Heatmap of Fatal Incidents by Country')
plt.xlabel('Fatal')
plt.ylabel('Country')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_df, cmap='crest', annot=True, fmt='d')  # Using Blues colormap for blues
plt.title('Heatmap of Fatal Incidents by Country')
plt.xlabel('Fatal')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# #### 3rd HYPOTHESIS: Sharks are not attacking more than before...maybe we are the problem?
# Let's see if there's a trend in the number of shark attacks over the years. If the frequency of attacks is increasing, decreasing, or remaining stable over time.

# %%
#Let's create the next subset
h3 = sharks.copy()
h3_columns = ["year", "type", "fatal"]
h3 = h3[h3_columns]
h3.head()
# Out:
#    year        type fatal
# 0  2018     Boating     N
# 1  2018  Unprovoked     N
# 2  2018     Invalid     N
# 3  2018  Unprovoked     N
# 4  2018    Provoked     N

# %%
#Keeping data only starting from 1800
h3 = h3[h3["year"] >= 1800]

# %%
#Cleaning a little bit "type"
h3 = h3[h3['type'] != 'Questionable']
h3 = h3[h3['type'] != 'Boatomg']

# %%
h3["type"].value_counts()
# Out:
# type
# Unprovoked      4429
# Provoked         563
# Invalid          542
# Sea Disaster     231
# Boating          202
# Boat             133
# Name: count, dtype: int64

# %%
#Cleaning "fatal" column
h3.loc[h3["fatal"] == " N", "fatal"] = "N"
h3.loc[h3["fatal"] == "M", "fatal"] = "UNKNOWN"
h3.loc[h3["fatal"] == "2017", "fatal"] = "UNKNOWN"
h3.loc[h3["fatal"] == "y", "fatal"] = "Y"
h3.loc[h3["fatal"] == "N ", "fatal"] = "N"

# %%
h3 = h3[h3['fatal'] != 'UNKNOWN']
h3 = h3[h3['fatal'] != 'Unknown']

# %%
#fatal incidents by type
stacked_df = h3.groupby(['type', 'fatal']).size().unstack(fill_value=0)
stacked_df.plot(kind='bar', stacked=True, figsize=(12, 6), color=['turquoise', 'teal'])

plt.title('Fatal Incidents by Type')
plt.xlabel('Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Fatal')
plt.show()

# %%
interval_size = 10
h3['year_interval'] = pd.cut(h3['year'], bins=range(min(h3['year']), max(h3['year']) + interval_size, interval_size))
grouped_data = h3.groupby(['year_interval', 'fatal']).size().unstack(fill_value=0)


plt.figure(figsize=(12, 6))
grouped_data.plot(kind='bar', stacked=True, color=['teal', 'turquoise'])
plt.title('Count of Fatal and Non-Fatal Incidents by Intervals')
plt.xlabel('Year Interval')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Fatal')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Elsa\AppData\Local\Temp\ipykernel_5740\1938300690.py:3: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
#distribution of fatal incidents by year
plt.figure(figsize=(12, 6))
sns.violinplot(x='year', y='fatal', data=h3,color='teal')
plt.title('Distribution of Fatal Incidents by Year')
plt.xlabel('Year')
plt.ylabel('Fatal')
plt.show()

# %% [markdown]
# ----

# %%
#attacks per year from 1800 to 2018,
sns.histplot(data=h3, x='year', hue='fatal', multiple='stack', kde=True, palette=['turquoise', 'teal'])
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %%
column_list = h1['activity'].tolist()

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
plt.subplots(figsize = (12,6))

wordcloud = WordCloud (
                    background_color = 'white',
                    width = 1500,
                    height = 1000).generate(','.join(str(v) for v in column_list))
plt.imshow(wordcloud, cmap='winter')
plt.axis('off')
plt.title('Word Cloud  - Activities')
plt.show()

# %% [markdown]
# ----
